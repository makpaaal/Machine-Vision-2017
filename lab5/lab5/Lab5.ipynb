# %% [markdown]
# # Lab5
# ## OpenCV - Fourier, Wavelet discrete transformations
# ### Installations
# * Download from https://pypi.python.org/pypi/opencv-python and follow instruction there
# * pip install opencv*.whl
# * pip install PyWavelets
# ### Tasks
# * In the LPF, make filtering region circle not square
# * Make High Pass Filter(HPF) as example take into consideration LPF
# * Make Band Pass Filter
# * Correct wavelet code

# %% [markdown]
# ## Fourier transformation

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from skimage import data
from skimage.draw import circle
# img = cv2.imread('xfiles.jpg',0)
img = data.camera()

img_float32 = np.float32(img)
print('Shape of original image:',img_float32.shape)
dft = cv2.dft(img_float32, flags = cv2.DFT_COMPLEX_OUTPUT)
# Now once you got the result, zero frequency component 
# (DC component) will be at top left corner. 
# If you want to bring it to center, you need
# to shift the result by \frac{N}{2} in both the directions. 
# This is simply done by the function, np.fft.fftshift().
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Shape of original image: (512, 512)

# %% [markdown]
# ### numpy.fft.fftshift

# %%
import numpy as np
# Return the Discrete Fourier Transform sample frequencies.
freqs = np.fft.fftfreq(10, 0.1)
print(freqs)
freqs_shifted = np.fft.fftshift(freqs)
print(freqs_shifted)
print(cv2.magnitude(freqs_shifted,freqs_shifted))
# Out:
# [ 0.  1.  2.  3.  4. -5. -4. -3. -2. -1.]
# [-5. -4. -3. -2. -1.  0.  1.  2.  3.  4.]
# [[ 7.07106781]
#  [ 5.65685425]
#  [ 4.24264069]
#  [ 2.82842712]
#  [ 1.41421356]
#  [ 0.        ]
#  [ 1.41421356]
#  [ 2.82842712]
#  [ 4.24264069]
#  [ 5.65685425]]

# %%
import numpy as np
# Return the Discrete Fourier Transform sample frequencies.
freqs = np.fft.fftfreq(10, 0.1)
print(freqs)
freqs_shifted = np.fft.fftshift(freqs)
print(freqs_shifted)
print(cv2.magnitude(freqs_shifted,freqs_shifted))
# Out:
# [ 0.  1.  2.  3.  4. -5. -4. -3. -2. -1.]
# [-5. -4. -3. -2. -1.  0.  1.  2.  3.  4.]
# [[ 7.07106781]
#  [ 5.65685425]
#  [ 4.24264069]
#  [ 2.82842712]
#  [ 1.41421356]
#  [ 0.        ]
#  [ 1.41421356]
#  [ 2.82842712]
#  [ 4.24264069]
#  [ 5.65685425]]

# %%
rows, cols = img.shape
crow, ccol = int(rows/2) , int(cols/2)     # center
flt_size = 15
# create a mask first, center square is 1, remaining all zeros
rr,cc=circle(crow,ccol,50)
mask_circle= np.ones((rows, cols, 2), np.uint8)

mask_circle[rr,cc]=0
rr,cc=circle(crow,ccol,40)
mask_circle[rr,cc]=1

mask_circle[crow-flt_size:crow+flt_size, ccol-flt_size:ccol+flt_size,:] = 1

# %%
new_shift = dft_shift*mask_circle
new_ishift = np.fft.ifftshift(new_shift)
img_back = cv2.idft(new_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
plt.imshow(mask_circle[:,:,0])
plt.show()

# %%
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from skimage import data
from sklearn.preprocessing import MinMaxScaler 
import pywt

img = data.camera()
imArray = np.float32(img)
imArray /= 255;

coeffs=pywt.wavedec2(imArray, 'haar')
coeffs_H=list(coeffs)  
coeffs_H[0] *= 0;  


#     # reconstruction
imArray_H=pywt.waverec2(coeffs_H, 'haar')
plt.imshow(imArray_H)
plt.show()

# %%
new_shift = dft_shift*mask_circle
new_ishift = np.fft.ifftshift(new_shift)
img_back = cv2.idft(new_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
magnitude_spectrum = 20*np.log(cv2.magnitude(new_shift[:,:,0],new_shift[:,:,1]))
plt.imshow(magnitude_spectrum[:,:])
plt.show()
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# C:\Users\MakpalPC\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
rows, cols = img.shape
crow, ccol = int(rows/2) , int(cols/2)     # center
flt_size = 15
# create a mask first, center square is 1, remaining all zeros
rr,cc=circle(crow,ccol,50)
mask_circle= np.zeros((rows, cols, 2), np.uint8)

mask_circle[rr,cc]=1


mask_circle[crow-flt_size:crow+flt_size, ccol-flt_size:ccol+flt_size,:] = 1

# %%
new_shift = dft_shift*mask_circle
new_ishift = np.fft.ifftshift(new_shift)
img_back = cv2.idft(new_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
plt.imshow(mask_circle[:,:,0])
plt.show()

# %%
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
